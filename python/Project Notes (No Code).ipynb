# %% [markdown]
# # Next Steps
#
# * Figure out why Python is not fitting HMM parameters correctly
#  * Currently: Matlab fits parameters correctly on data generated by Python or Matlab
#  * Currently: Python estimates jump around, Matlab estimates are consistent
# * Decide on whether to work with Python or Matlab
# * Update code to learn parameters on an arbitrary number of concepts
# * Download and clean real student data
# * Train HMMs on real student data
#  * Validate model fit by testing trained model's ability to predict new student data
